# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict 
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
class BlogState(TypedDict): 
    
    title: str 
    outline: str 
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    
    # fetch title 
    title = state['title']
    
    # call llm gen outline 
    prompt = f'Generate a detailed outline for a blog oon the topic - {title}'
    outline = llm.invoke(prompt).content
    
    # update state 
    state['outline'] = outline 
    
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    
    title = state['title']
    outline = state['outline']
    
    prompt = f'Write a detailed blog on the title - {title} using the following outline \n {outline}'
    
    content = llm.invoke(prompt).content
    
    state['content'] = content
    
    return state

# %%
graph = StateGraph(BlogState)

# nodes 
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges 
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': "**Title:** The Rise of AI in India: Trends, Opportunities, and Challenges\n\n**I. Introduction**\n\n* Brief overview of AI and its growing significance globally\n* Significance of India in the AI landscape\n* Thesis statement: India is poised to become a major player in the global AI market, driven by government initiatives, innovative startups, and a large talent pool.\n\n**II. Government Initiatives and Support**\n\n* Overview of government policies and initiatives promoting AI adoption in India (e.g., Digital India, Start-up India, and Make in India)\n* Discussion of the National AI Portal, a platform for AI-related information, research, and innovation\n* Analysis of the National Education Policy 2020, which emphasizes AI education and research\n\n**III. AI Startups in India**\n\n* Overview of the Indian AI startup ecosystem, including key players and their focus areas\n* Discussion of incubators, accelerators, and funding opportunities for AI startups\n* Examples of successful AI startups in India, such as:\n\t+ Fractal Analytics\n\t+ Hike Messenger\n\t+ Zeta\n\t+ SigTuple\n\n**IV. AI Adoption in Key Industries**\n\n* Discussion of AI adoption in various Indian industries, including:\n\t+ Banking and Finance (e.g., chatbots, credit scoring)\n\t+ Healthcare (e.g., medical imaging, patient diagnosis)\n\t+ E-commerce (e.g., product recommendation, supply chain optimization)\n\t+ Transportation (e.g., autonomous vehicles, route optimization)\n\n**V. AI Talent and Education**\n\n* Overview of the growing demand for AI professionals in India\n* Discussion of AI education initiatives, including:\n\t+ AI-focused courses and programs (e.g., IITs, IIMs)\n\t+ Online learning platforms (e.g., Coursera, edX)\n\t+ Research collaborations with international universities and institutions\n\n**VI. Challenges and Concerns**\n\n* Discussion of the challenges and concerns associated with AI adoption in India, including:\n\t+ Data quality and availability\n\t+ Cybersecurity risks\n\t+ Job displacement and skills gap\n\t+ Bias and ethics in AI decision-making\n\n**VII. Conclusion**\n\n* Summary of the rise of AI in India\n* Future outlook and projections for the Indian AI market\n* Final thoughts on the importance of AI adoption and innovation in India's growth story.\n\n**VIII. Appendices**\n\n* List of AI-related government initiatives and policies\n* List of key AI startups in India\n* List of AI-focused courses and programs in Indian universities\n* List of online learning platforms for AI education\n\n**IX. References**\n\n* List of sources used in the blog post, formatted according to the chosen citation style.", 'content': "**The Rise of AI in India: Trends, Opportunities, and Challenges**\n\n**I. Introduction**\n\nArtificial intelligence (AI) has been transforming the way businesses operate and societies function globally. The growing significance of AI is evident in its applications across various industries, from healthcare and finance to transportation and education. India, with its large talent pool, government initiatives, and innovative startups, is poised to become a major player in the global AI market.\n\nIndia's strategic location, demographic diversity, and economic growth make it an attractive hub for AI adoption and innovation. The government's support and initiatives have created a conducive environment for AI startups, research, and education. This blog post will explore the trends, opportunities, and challenges associated with the rise of AI in India.\n\n**II. Government Initiatives and Support**\n\nThe Indian government has launched various initiatives to promote AI adoption and innovation in the country. Some notable examples include:\n\n* **Digital India**: A flagship program aimed at transforming India into a digitally empowered society and knowledge economy. The program emphasizes the use of AI and data analytics to drive digital transformation.\n* **Start-up India**: A  ...

# %%
print(final_state['outline'])
# Out:
# **Title:** The Rise of AI in India: Trends, Opportunities, and Challenges
#
# **I. Introduction**
#
# * Brief overview of AI and its growing significance globally
# * Significance of India in the AI landscape
# * Thesis statement: India is poised to become a major player in the global AI market, driven by government initiatives, innovative startups, and a large talent pool.
#
# **II. Government Initiatives and Support**
#
# * Overview of government policies and initiatives promoting AI adoption in India (e.g., Digital India, Start-up India, and Make in India)
# * Discussion of the National AI Portal, a platform for AI-related information, research, and innovation
# * Analysis of the National Education Policy 2020, which emphasizes AI education and research
#
# **III. AI Startups in India**
#
# * Overview of the Indian AI startup ecosystem, including key players and their focus areas
# * Discussion of incubators, accelerators, and funding opportunities for AI startups
# * Examples of successful AI startups in India, such as:
# 	+ Fractal Analytics
# 	+ Hike Messenger
# 	+ Zeta
# 	+ SigTuple
#
# **IV. AI Adoption in Key Industries**
#
# * Discussion of AI adoption in various Indian industries, including:
# 	+ Banking and Finance (e.g., chatbots, credit scoring)
# 	+ Healthcare (e.g., medical imaging, patient diagnosis)
# 	+ E-commerce (e.g., product recommendation, supply chain optimization)
# 	+ Transportation (e.g., autonomous vehicles, route optimization)
#
# **V. AI Talent and Education**
#
# * Overview of the growing demand for AI professionals in India
# * Discussion of AI education initiatives, including:
# 	+ AI-focused courses and programs (e.g., IITs, IIMs)
# 	+ Online learning platforms (e.g., Coursera, edX)
# 	+ Research collaborations with international universities and institutions
#
# **VI. Challenges and Concerns**
#
# * Discussion of the challenges and concerns associated with AI adoption in India, including:
# 	+ Data quality and availability
# 	+ Cybersecurity risks
# 	+ Job displacement and skills gap
# 	+ Bias and ethics in AI decision-making
#
# **VII. Conclusion**
#
# * Summary of the rise of AI in India
# * Future outlook and projections for the Indian AI market
# * Final thoughts on the importance of AI adoption and innovation in India's growth story.
#
# **VIII. Appendices**
#
# * List of AI-related government initiatives and policies
# * List of key AI startups in India
# * List of AI-focused courses and programs in Indian universities
# * List of online learning platforms for AI education
#
# **IX. References**
#
# * List of sources used in the blog post, formatted according to the chosen citation style.

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: Trends, Opportunities, and Challenges**
#
# **I. Introduction**
#
# Artificial intelligence (AI) has been transforming the way businesses operate and societies function globally. The growing significance of AI is evident in its applications across various industries, from healthcare and finance to transportation and education. India, with its large talent pool, government initiatives, and innovative startups, is poised to become a major player in the global AI market.
#
# India's strategic location, demographic diversity, and economic growth make it an attractive hub for AI adoption and innovation. The government's support and initiatives have created a conducive environment for AI startups, research, and education. This blog post will explore the trends, opportunities, and challenges associated with the rise of AI in India.
#
# **II. Government Initiatives and Support**
#
# The Indian government has launched various initiatives to promote AI adoption and innovation in the country. Some notable examples include:
#
# * **Digital India**: A flagship program aimed at transforming India into a digitally empowered society and knowledge economy. The program emphasizes the use of AI and data analytics to drive digital transformation.
# * **Start-up India**: A scheme launched to promote entrepreneurship and innovation in the country. The program offers support to startups, including funding, incubation, and mentorship.
# * **Make in India**: A program aimed at promoting manufacturing and innovation in India. The program encourages the use of AI and automation in manufacturing processes.
# * **National AI Portal**: A platform launched to provide information, research, and innovation in AI. The portal aims to promote AI adoption and innovation in various industries.
#
# The National Education Policy 2020 emphasizes the importance of AI education and research in Indian universities. The policy aims to promote interdisciplinary research, including AI and data science, to address the country's development challenges.
#
# **III. AI Startups in India**
#
# India's AI startup ecosystem is growing rapidly, with many innovative startups emerging in various areas, including:
#
# * **Fractal Analytics**: A data science and AI startup that offers predictive analytics and AI-powered solutions to businesses.
# * **Hike Messenger**: A messaging app that uses AI-powered chatbots to offer a personalized experience to users.
# * **Zeta**: A financial technology startup that uses AI-powered algorithms to offer credit scoring and lending solutions.
# * **SigTuple**: A healthcare startup that uses AI-powered algorithms to analyze medical images and diagnose diseases.
#
# Incubators, accelerators, and funding opportunities are available for AI startups in India. Some notable examples include:
#
# * **Incorporate**: An incubator that offers funding, mentorship, and resources to startups.
# * **Tata Accelerate**: An accelerator that offers funding, mentorship, and resources to startups.
# * **Venture Catalyst**: A funding platform that offers funding to startups in the AI and data science space.
#
# **IV. AI Adoption in Key Industries**
#
# AI adoption is gaining momentum in various Indian industries, including:
#
# * **Banking and Finance**: AI-powered chatbots are being used to offer customer support and services. Credit scoring and lending solutions are also being offered using AI-powered algorithms.
# * **Healthcare**: AI-powered algorithms are being used to analyze medical images and diagnose diseases. Chatbots are also being used to offer patient support and services.
# * **E-commerce**: AI-powered algorithms are being used to offer product recommendations and personalized experiences to customers. Supply chain optimization is also being done using AI-powered algorithms.
# * **Transportation**: AI-powered algorithms are being used to optimize routes and schedules for public transport. Autonomous vehicles are also being tested in India.
#
# **V. AI Talent and Education**
#
# The demand for AI professionals in India is growing rapidly. To address this demand, many Indian universities are offering AI-focused courses and programs. Some notable examples include:
#
# * **IITs**: Indian Institutes of Technology (IITs) are offering AI-focused courses and programs, including M.Tech and Ph.D. programs.
# * **IIMs**: Indian Institutes of Management (IIMs) are offering AI-focused courses and programs, including MBA and Ph.D. programs.
# * **Coursera**: An online learning platform that offers AI-focused courses and programs from top universities worldwide.
# * **edX**: An online learning platform that offers AI-focused courses and programs from top universities worldwide.
#
# Research collaborations are also being established between Indian universities and international universities and institutions to promote AI research and innovation.
#
# **VI. Challenges and Concerns**
#
# While AI adoption is gaining momentum in India, several challenges and concerns need to be addressed, including:
#
# * **Data quality and availability**: High-quality data is essential for AI adoption, but data quality and availability are major concerns in India.
# * **Cybersecurity risks**: AI adoption increases the risk of cybersecurity breaches, which can compromise sensitive data and disrupt business operations.
# * **Job displacement and skills gap**: AI adoption may lead to job displacement and a skills gap, particularly in sectors where automation is high.
# * **Bias and ethics in AI decision-making**: AI decision-making can be biased, which can lead to unfair outcomes and ethical issues.
#
# **VII. Conclusion**
#
# The rise of AI in India is a significant trend that is expected to continue in the coming years. Government initiatives, innovative startups, and a large talent pool are driving AI adoption and innovation in India. While challenges and concerns need to be addressed, the opportunities offered by AI adoption are vast, and India is poised to become a major player in the global AI market.
#
# **VIII. Appendices**
#
# * List of AI-related government initiatives and policies:
# 	+ Digital India
# 	+ Start-up India
# 	+ Make in India
# 	+ National AI Portal
# * List of key AI startups in India:
# 	+ Fractal Analytics
# 	+ Hike Messenger
# 	+ Zeta
# 	+ SigTuple
# * List of AI-focused courses and programs in Indian universities:
# 	+ IITs
# 	+ IIMs
# 	+ Coursera
# 	+ edX
# * List of online learning platforms for AI education:
# 	+ Coursera
# 	+ edX
#
# **IX. References**
#
# * National Education Policy 2020. (2020). Ministry of Education, Government of India.
# * Digital India. (2020). Ministry of Electronics and Information Technology, Government of India.
# * Start-up India. (2020). Ministry of Commerce and Industry, Government of India.
# * Make in India. (2020). Ministry of Commerce and Industry, Government of India.
# * Fractal Analytics. (2020). Fractal Analytics Website.
# * Hike Messenger. (2020). Hike Messenger Website.
# * Zeta. (2020). Zeta Website.
# * SigTuple. (2020). SigTuple Website.
# * Incorporate. (2020). Incorporate Website.
# * Tata Accelerate. (2020). Tata Accelerate Website.
# * Venture Catalyst. (2020). Venture Catalyst Website.
