# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict 
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
# create a state 

class LLMState(TypedDict):
    
    question: str 
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:
    
    # extract the question from state 
    question = state['question']
    
    # form a prompt 
    prompt = f'Answer the following question {question}'
    
    # ask that question to the LLM
    answer = llm.invoke(prompt).content
    
    # update the answer in the state 
    state['answer'] = answer
    
    return state

# %%
# create our graph 

graph = StateGraph(LLMState)

# add nodes 
graph.add_node('llm_qa', llm_qa)

# add edges 
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile 
workflow = graph.compile()

# %%
# execute 

initial_state = {'question': 'When will IPL 2026 start?'}

final_state = workflow.invoke(initial_state)

print(final_state['answer'])
# Out:
# I'm not aware of any information regarding the start date of IPL 2026. However, the Board of Control for Cricket in India (BCCI) typically announces the schedule for the Indian Premier League (IPL) a few months in advance.
#
# IPL 2024 started on March 2, 2024.
#
# It is most likely that IPL 2026 will be announced in the future. For up-to-date information on IPL 2026, I recommend checking the official website of the BCCI or reputable news sources for the latest updates.
